# %% [markdown]
# # 3. Feature Engineering
#
# Bu notebook yeni feature turetme ve feature selection surecini icerir.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, cross_val_score
import lightgbm as lgb

RANDOM_STATE = 42
BASELINE_AUC = 0.0  # Onceki notebook'tan

# %% [markdown]
# ## 1. Feature Engineering Faz 1

# %%
# Aggregation features, ratio features vb.

# %% [markdown]
# ## 2. Feature Engineering Faz 2

# %%
# Polynomial features, binning vb.

# %% [markdown]
# ## 3. Feature Selection

# %%
# Dusuk varyans, yuksek korelasyon, feature importance

# %% [markdown]
# ## 4. Sonuclar
#
# | Faz | AUC | Degisim |
# |-----|-----|--------|
# | Baseline | X.XXXX | - |
# | Faz 1 | X.XXXX | +X.XX% |
# | Faz 2 | X.XXXX | +X.XX% |
